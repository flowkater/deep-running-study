# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Activate Function

# %% [markdown]
# ## Sigmoid

# %%
def sigmoid(n):
    return 1 / (1 + np.exp(-n))

xx = np.linspace(start=-10.0, stop=10.0)
yy = sigmoid(xx)

plt.plot(xx, yy)

# %%
def sigmoid_derivative(n):
    return sigmoid(n) * (1 - sigmoid(n))

xx = np.linspace(start=-10.0, stop=10.0, num=150)
yy = sigmoid_derivative(xx)

plt.plot(xx, yy)

# %% [markdown]
# ## ReLU

# %%
def relu(n):
    return n * (0 < n)

xx = np.linspace(start=-10.0, stop=10.0, num=150)
yy = relu(xx)

plt.plot(xx, yy)

# %%
def relu_derivative(n):
    return 1 * (0 < n)

xx = np.linspace(start=-10.0, stop=10.0, num=150)
yy = relu_derivative(xx)

plt.plot(xx, yy)

# %% [markdown]
# ## Benchmark

# %%
# %time tmp = [sigmoid(i) for i in range(1000000)]
# %time tmp = [relu(i) for i in range(1000000)]
# Out:
# CPU times: user 1.77 s, sys: 25.6 ms, total: 1.79 s
# Wall time: 1.8 s
# CPU times: user 175 ms, sys: 17.1 ms, total: 192 ms
# Wall time: 193 ms

# %%
# %time tmp = [sigmoid_derivative(i) for i in range(1000000)]
# %time tmp = [relu_derivative(i) for i in range(1000000)]
# Out:
# CPU times: user 4.18 s, sys: 31.6 ms, total: 4.21 s
# Wall time: 4.22 s
# CPU times: user 176 ms, sys: 8.13 ms, total: 184 ms
# Wall time: 184 ms

# %% [markdown]
# # Load MNIST Dataset

# %%
from keras.datasets import mnist

((X_train, y_train), (X_test, y_test)) = mnist.load_data()

# %%
figure, axes = plt.subplots(nrows=2, ncols=5)
figure.set_size_inches(18, 8)

print("label = {0}".format(y_train[0:15]))

axes[0][0].matshow(X_train[0])
axes[0][1].matshow(X_train[1])
axes[0][2].matshow(X_train[2])
axes[0][3].matshow(X_train[3])
axes[0][4].matshow(X_train[4])
axes[1][0].matshow(X_train[5])
axes[1][1].matshow(X_train[6])
axes[1][2].matshow(X_train[7])
axes[1][3].matshow(X_train[8])
axes[1][4].matshow(X_train[9])
# Out:
# label = [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1]

# %% [markdown]
# # Preprocessing

# %%
X_train = X_train.reshape(60000, 28 * 28)
X_test = X_test.reshape(10000, 28 * 28)

print(X_train.shape, X_test.shape)
# Out:
# (60000, 784) (10000, 784)

# %%
from keras.utils import to_categorical

y_train_hot = to_categorical(y_train)
y_test_hot = to_categorical(y_test)

print(y_train_hot.shape, y_test_hot.shape)
# Out:
# (60000, 10) (10000, 10)

# %% [markdown]
# # Train

# %% [markdown]
# ## Sigmoid

# %%
from time import time

start = time()

num_epoch = 100
learning_rate = 0.000001

w1 = np.random.uniform(low=-np.sqrt(6 / (784 + 100)), high=np.sqrt(6 / (784 + 100)), size=(784, 100))
w2 = np.random.uniform(low=-np.sqrt(6 / (100 + 100)), high=np.sqrt(6 / (100 + 100)), size=(100, 100))
w3 = np.random.uniform(low=-np.sqrt(6 / (100 + 10)), high=np.sqrt(6 / (100 + 10)), size=(100, 10))


sigmoid_epoch_list = []

for epoch in range(num_epoch):
    z1 = X_train.dot(w1)
    a1 = sigmoid(z1)
    
    z2 = a1.dot(w2)
    a2 = sigmoid(z2)
    
    z3 = a2.dot(w3)
    a3 = sigmoid(z3)    
    
    y_predict = np.argmax(a3, axis=1)
    error = (y_train != y_predict).mean()
    
    if epoch % 10 == 0:
        print("{0:2} error = {1:.5f}".format(epoch, error))
    
    end = time()
    sigmoid_epoch_list.append({
        'time': end - start,
        'error': error
    })
# Out:
#  0 error = 0.88948
# 10 error = 0.88948
# 20 error = 0.88948
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-6a29b8abc1f2> in <module>()
#      18
#      19     z2 = a1.dot(w2)
# ---> 20     a2 = sigmoid(z2)
#      21
#      22     z3 = a2.dot(w3)
#
# <ipython-input-3-85e09af3c867> in sigmoid(n)
#       1 def sigmoid(n):
# ----> 2     return 1 / (1 + np.exp(-n))
#       3
#       4 xx = np.linspace(start=-10.0, stop=10.0)
#       5 yy = sigmoid(xx)
#
# KeyboardInterrupt:

# %%
time() - start
# Out:
# 4.5504820346832275
